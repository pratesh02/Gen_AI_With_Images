# %% [markdown]
#  INTRODUCTION TO opencv and image processing

# %%
# pip install opencv-python

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'C:\Users\pshett4\OneDrive - MORNINGSTAR INC\FSDS\Gen AI with Image\Elephant.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (408, 612, 3)

# %%
plt.imshow(img)

# %% [markdown]
# # Matplotlib R G B
# # OpenCV B G R

# %%
img
# Out:
# array([[[223, 207, 195],
#         [219, 203, 191],
#         [214, 198, 186],
#         ...,
#         [207, 196, 182],
#         [206, 195, 181],
#         [206, 195, 181]],
#
#        [[221, 205, 193],
#         [217, 201, 189],
#         [213, 197, 185],
#         ...,
#         [206, 195, 181],
#         [206, 195, 181],
#         [205, 194, 180]],
#
#        [[219, 203, 191],
#         [216, 200, 188],
#         [211, 195, 183],
#         ...,
#         [205, 194, 180],
#         [205, 194, 180],
#         [204, 193, 179]],
#
#        ...,
#
#        [[ 62,  99, 149],
#         [ 52,  92, 141],
#         [ 64, 106, 159],
#         ...,
#         [ 73, 125, 166],
#         [ 68, 118, 160],
#         [ 59, 111, 151]],
#
#        [[ 75, 115, 164],
#         [ 82, 123, 172],
#         [ 68, 110, 163],
#         ...,
#         [ 89, 141, 187],
#         [ 87, 137, 183],
#         [ 86, 139, 182]],
#
#        [[ 57,  98, 147],
#         [ 87, 130, 179],
#         [ 65, 107, 160],
# ...

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[195, 207, 223],
#         [191, 203, 219],
#         [186, 198, 214],
#         ...,
#         [182, 196, 207],
#         [181, 195, 206],
#         [181, 195, 206]],
#
#        [[193, 205, 221],
#         [189, 201, 217],
#         [185, 197, 213],
#         ...,
#         [181, 195, 206],
#         [181, 195, 206],
#         [180, 194, 205]],
#
#        [[191, 203, 219],
#         [188, 200, 216],
#         [183, 195, 211],
#         ...,
#         [180, 194, 205],
#         [180, 194, 205],
#         [179, 193, 204]],
#
#        ...,
#
#        [[149,  99,  62],
#         [141,  92,  52],
#         [159, 106,  64],
#         ...,
#         [166, 125,  73],
#         [160, 118,  68],
#         [151, 111,  59]],
#
#        [[164, 115,  75],
#         [172, 123,  82],
#         [163, 110,  68],
#         ...,
#         [187, 141,  89],
#         [183, 137,  87],
#         [182, 139,  86]],
#
#        [[147,  98,  57],
#         [179, 130,  87],
#         [160, 107,  65],
# ...

# %%
plt.imshow(fix_img)

# %% [markdown]
# # https://docs.opencv.org/3.4/d8/d01/group__imgproc__color__conversions.html
# # color documentation

# %%
fix_img.shape
# Out:
# (408, 612, 3)

# %%
img_gray = cv2.imread(r'C:\Users\pshett4\OneDrive - MORNINGSTAR INC\FSDS\Gen AI with Image\Elephant.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.min()
# Out:
# 0

# %%
img_gray.max()
# Out:
# 251

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(img_gray, cmap = 'BuPu')

# %%
plt.imshow(img_gray, cmap = 'magma')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (408, 612, 3)

# %%
img.shape
# Out:
# (408, 612, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(74,108))

# %%
fix_img_1.shape
# Out:
# (108, 74, 3)

# %%
plt.imshow(fix_img_1)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(fix_img_2)

# %%
img3 = cv2.flip(img,0)
plt.imshow(img3)

# %%
img3 = cv2.flip(img,1)
plt.imshow(img3)

# %%
cv2.imwrite('new_elephant_img.jpg',img3)
# Out:
# True

# %%
pwd
# Out:
# 'C:\\Users\\pshett4\\OneDrive - MORNINGSTAR INC\\FSDS'
